# %%
import pandas as pd
from matplotlib import colormaps
import matplotlib.pyplot as plt

# %%
superstore=pd.read_csv("superstore_cleaned.csv", sep=",", encoding="latin-1")
superstore.head(5)
# Out:
#          Order ID  Order Date  Order Day Order Weekday  Order Month  \
# 0  CA-2013-152156  2013-11-09          9      Saturday           11
# 1  CA-2013-152156  2013-11-09          9      Saturday           11
# 2  CA-2013-138688  2013-06-13         13      Thursday            6
# 3  US-2012-108966  2012-10-11         11      Thursday           10
# 4  US-2012-108966  2012-10-11         11      Thursday           10
#
#    Order Year  Order Quarter   Ship Date  Ship Day Ship Weekday  ...  \
# 0        2013              4  2013-11-12        12      Tuesday  ...
# 1        2013              4  2013-11-12        12      Tuesday  ...
# 2        2013              2  2013-06-17        17       Monday  ...
# 3        2012              4  2012-10-18        18     Thursday  ...
# 4        2012              4  2012-10-18        18     Thursday  ...
#
#         Product ID         Category  Sub-Category  \
# 0  FUR-BO-10001798        Furniture     Bookcases
# 1  FUR-CH-10000454        Furniture        Chairs
# 2  OFF-LA-10000240  Office Supplies        Labels
# 3  FUR-TA-10000577        Furniture        Tables
# 4  OFF-ST-10000760  Office Supplies       Storage
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
#
#   Discount    Profit Price per Piece  Profit per Piece
# 0     0.00   41.9136        130.9800           20.9568
# 1     0.00  219.5820        243.9800           73.1940
# 2     0.00    6.8714          7.3100            3.4357
# 3     0.45 -383.0310        191.5155          -76.6062
# 4     0.20    2.5164         11.1840            1.2582
#
# [5 rows x 31 columns]

# %%
Anzahl=superstore["Category"].count()
kategorien=superstore["Category"].value_counts()
rel_kategorien=(kategorien[["Furniture","Office Supplies","Technology"]]/Anzahl*100).round(1)

# %%
rel_kategorien.plot(kind="pie",ylabel="",autopct="%1.1f%%",explode=(0,0,0.2),title=f"Main Categories (Absolute data: {Anzahl} shipments)",startangle=35)
# Out:
# <Axes: title={'center': 'Main Categories (Absolute data: 9994 shipments)'}>

# %%
rel_kategorien.plot(kind="pie",ylabel="",autopct="%1.1f%%",explode=(0.2,0,0),title=f"Main Categories (Absolute data: {Anzahl} shipments)",startangle=-40)
# Out:
# <Axes: title={'center': 'Main Categories (Absolute data: 9994 shipments)'}>

# %%
rel_kategorien.plot(kind="pie",ylabel="",autopct="%1.1f%%",explode=(0,0.2,0),title=f"Main Categories (Absolute data: {Anzahl} shipments)",startangle=180)
# Out:
# <Axes: title={'center': 'Main Categories (Absolute data: 9994 shipments)'}>

# %%
#print(superstore.groupby("Category")["Sub-Category"].nunique()) #--> 17 Kategorien
unterkategorie=superstore['Sub-Category'].unique()

Kategorie1=superstore["Category"]=="Technology"
Kategorie2=superstore["Category"]=="Furniture"
Kategorie3=superstore["Category"]=="Office Supplies"

AnzahlTech=superstore[Kategorie1]["Sub-Category"].count()
EintraegeTech=superstore[Kategorie1]["Sub-Category"].nunique()
Technology=superstore[Kategorie1]["Sub-Category"].value_counts()
Technology.plot(kind="pie",ylabel="",autopct="%1.1f%%",explode=(0,0,0,0),title=f"Sub-Category: Technology (Absolute data: {AnzahlTech} shipments)",startangle=0,colormap="Greens_r")#,colors = pd.Pastel1(range(len(Technology))))
# Out:
# <Axes: title={'center': 'Sub-Category: Technology (Absolute data: 1847 shipments)'}>

# %%
AnzahlFurniture=superstore[Kategorie2]["Sub-Category"].count()
EintraegeFurniture=superstore[Kategorie2]["Sub-Category"].nunique()
Furniture=superstore[Kategorie2]["Sub-Category"].value_counts()
Furniture.plot(kind="pie",ylabel="",autopct="%1.1f%%",explode=(0,0,0,0),title=f"Sub-Category: Furniture (Absolute data: {AnzahlFurniture} shipments)",startangle=0,colormap="Blues_r")
# Out:
# <Axes: title={'center': 'Sub-Category: Furniture (Absolute data: 2121 shipments)'}>

# %%
AnzahlOffice=superstore[Kategorie3]["Sub-Category"].count()
EintraegeOffice=superstore[Kategorie3]["Sub-Category"].nunique()
OfficeSupplies=superstore[Kategorie3]["Sub-Category"].value_counts()
OfficeSupplies.plot(kind="pie",ylabel="",autopct="%1.1f%%",explode=(0,0,0,0,0,0,0,0,0),title=f"Sub-Category: Office Supplies (Absolute data: {AnzahlOffice} shipments)",startangle=0,colormap="Oranges_r")
print(len(superstore))
print(AnzahlTech+AnzahlOffice+AnzahlFurniture)
print("Prüfung i.O. Anzahlen der Gegenstände in Kategorien sind gleich den Anzahlen der Zeilen")
#list(colormaps)
# Out:
# 9994
# 9994
# Prüfung i.O. Anzahlen der Gegenstände in Kategorien sind gleich den Anzahlen der Zeilen

# %%
superstore.head()
# Out:
#          Order ID  Order Date  Order Day Order Weekday  Order Month  \
# 0  CA-2013-152156  2013-11-09          9      Saturday           11
# 1  CA-2013-152156  2013-11-09          9      Saturday           11
# 2  CA-2013-138688  2013-06-13         13      Thursday            6
# 3  US-2012-108966  2012-10-11         11      Thursday           10
# 4  US-2012-108966  2012-10-11         11      Thursday           10
#
#    Order Year  Order Quarter   Ship Date  Ship Day Ship Weekday  ...  \
# 0        2013              4  2013-11-12        12      Tuesday  ...
# 1        2013              4  2013-11-12        12      Tuesday  ...
# 2        2013              2  2013-06-17        17       Monday  ...
# 3        2012              4  2012-10-18        18     Thursday  ...
# 4        2012              4  2012-10-18        18     Thursday  ...
#
#         Product ID         Category  Sub-Category  \
# 0  FUR-BO-10001798        Furniture     Bookcases
# 1  FUR-CH-10000454        Furniture        Chairs
# 2  OFF-LA-10000240  Office Supplies        Labels
# 3  FUR-TA-10000577        Furniture        Tables
# 4  OFF-ST-10000760  Office Supplies       Storage
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
#
#   Discount    Profit Price per Piece  Profit per Piece
# 0     0.00   41.9136        130.9800           20.9568
# 1     0.00  219.5820        243.9800           73.1940
# 2     0.00    6.8714          7.3100            3.4357
# 3     0.45 -383.0310        191.5155          -76.6062
# 4     0.20    2.5164         11.1840            1.2582
#
# [5 rows x 31 columns]

# %%
superstore["Product Name"].value_counts() #am meisten werden "Staples" gekauft
TopdreiVerkauft=superstore["Product Name"].value_counts().iloc[:3].sort_values(ascending=True)
print(TopdreiVerkauft)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 5))
bars = ax.barh(TopdreiVerkauft.index,TopdreiVerkauft)#width=0.6)

# Set individual colors for each bar
colors = ['#1f77b4', "#ff9900", "#068706"]  # Dark blue, Orange, Green
for bar, color in zip(bars, colors):
    bar.set_color(color)

# Customize the plot
ax.set_title('Top three most selled products', pad=20,fontweight="bold")
ax.set_xlabel('Quantity selled', labelpad=20)
ax.set_ylabel("", labelpad=20)

#wert an den jeweiligen balken schreiben:
for i, x in enumerate(TopdreiVerkauft):
    ax.text(x+1, i+0, f'{x:,.0f} ', va='center', fontsize=10)
#TopdreiVerkauft.plot(kind="bar",title=f"Top ten most selled products",rot=90,ylabel="Quantity Selled")
# Out:
# Product Name
# KI Adjustable-Height Table     18
# Avery Non-Stick Binders        20
# Staples                       227
# Name: count, dtype: int64

# %%
"""
"plotly" mal angucken: plotly express

ENTSCHIEDEN DAS DAS NIX TAUGT!
superstore["Product Name"].value_counts()
WorsttenVerkauft=superstore["Product Name"].value_counts().sort_values(ascending=True).iloc[:10]
print(WorsttenVerkauft)
# Create the plot
fig, ax = plt.subplots(figsize=(5, 5))
bars = ax.bar(WorsttenVerkauft.index,WorsttenVerkauft,width=0.6)
# Set individual colors for each bar
colors = ['#1f77b4', "#ff9900", "#068706"]  # Dark blue, Orange, Green
for bar, color in zip(bars, colors):
    bar.set_color(color)
# Customize the plot
ax.set_title('Worst ten selled products SINNLOS NICHT NUTZEN', pad=20)
ax.set_ylabel('Quantity Selled', labelpad=20)
ax.set_xlabel("", labelpad=20)
#wert an den jeweiligen balken schreiben:
for i, x in enumerate(WorsttenVerkauft):
    ax.text(i-0.1, x+0.02, f'{x:,.0f} ', va='center', fontsize=10)
""";

# %%
superstore["Product Name"].value_counts()
Verkauft=superstore["Product Name"].value_counts().sort_values(ascending=True)

Verkauft.plot(kind="line",grid=True,xlabel="Product")
#WorstVerkauft
# Out:
# <Axes: xlabel='Product'>

# %%
Verkauft[Verkauft<21].plot(kind="line",grid=True)
# Out:
# <Axes: xlabel='Product Name'>

# %%
#PosProfit=superstore["Profit"]>0
#NegProfit=superstore["Profit"]<=0
Pos_Kategorie=superstore.groupby("Sub-Category")["Profit"].sum().sort_values().round(2)
Pos_Kategorie=Pos_Kategorie/1000
Pos_Kategorie.round(2)
Neg_Kategorie=superstore.groupby("Sub-Category")["Profit"].sum().sort_values().round(2)
Neg_Kategorie=Neg_Kategorie*(-1)/1000

#print(Pos_Kategorie)
#Pos_Kategorie.plot(kind="line",x="Product Name",y="Profit")

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.barh(Pos_Kategorie.index,Pos_Kategorie)#, width=0.6)

# Set individual colors for each bar
colors = ["red","red","red"]#'#1f77b4', "#ff9900", "#068706"]  # Dark blue, Orange, Green
for bar, color in zip(bars, colors):
    bar.set_color(color)

# Customize the plot
ax.set_title('Profit of "Sub-Categories"', pad=20,fontweight="bold")
ax.set_xlabel('Profit in 1000 $', labelpad=20,fontweight="bold")
ax.set_ylabel("", labelpad=20,fontweight="bold")

#wert an den jeweiligen balken schreiben:
for i, x in enumerate(Pos_Kategorie):
    ax.text(x+0.1, i+0, f'{x:,.1f} ', va='center', fontsize=10)

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.barh(Neg_Kategorie.index,Neg_Kategorie)#width=0.6)

# Set individual colors for each bar
rot=[]
[rot.append("red") for i in enumerate(Neg_Kategorie)]

colors = rot#'#1f77b4', "#ff9900", "#068706"]  # Dark blue, Orange, Green
for bar, color in zip(bars, colors):
    bar.set_color(color)

# Customize the plot
ax.set_title('VERALTET Unprofitable "Sub-Categories"', pad=20,fontweight="bold")
ax.set_xlabel('Loss in 1000 $', labelpad=20,fontweight="bold")
ax.set_ylabel("", labelpad=20,fontweight="bold")

#wert an den jeweiligen balken schreiben:
for i, x in enumerate(Neg_Kategorie):
    ax.text(x+0.2, i+0, f'{x:,.1f} ', va='center', fontsize=10)

# %%
Pos_KatGegenstand=superstore.groupby("Product Name")["Profit"].sum().sort_values(ascending=False).round(2)
PosKatTopten=Pos_KatGegenstand.iloc[:10].sort_values()/1000
#print(PosKatTopten)
Neg_KatGegenstand=superstore.groupby("Product Name")["Profit"].sum().sort_values().round(2)
NegKatTopten=Neg_KatGegenstand.iloc[:10].sort_values()*(-1)/1000

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.barh(PosKatTopten.index,PosKatTopten)#width=0.6)

# Set individual colors for each bar
colors = []#'#1f77b4', "#ff9900", "#068706"]  # Dark blue, Orange, Green
for bar, color in zip(bars, colors):
    bar.set_color(color)

# Customize the plot
ax.set_title('Top ten profitable products', pad=20,fontweight="bold")
ax.set_xlabel('Profit in 1000 $', labelpad=20,fontweight="bold")
ax.set_ylabel("", labelpad=20,fontweight="bold")

#wert an den jeweiligen balken schreiben:
for i, x in enumerate(PosKatTopten):
    ax.text(x+0.1, i+0, f'{x:,.1f} ', va='center', fontsize=10)

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.barh(NegKatTopten.index,NegKatTopten)#width=0.6)

# Set individual colors for each bar
rot=[]
[rot.append("red") for i in enumerate(NegKatTopten)]

colors = rot#'#1f77b4', "#ff9900", "#068706"]  # Dark blue, Orange, Green
for bar, color in zip(bars, colors):
    bar.set_color(color)

# Customize the plot
ax.set_title('Top ten unprofitable products', pad=20,fontweight="bold")
ax.set_xlabel('Loss in 1000 $', labelpad=20,fontweight="bold")
ax.set_ylabel("", labelpad=20,fontweight="bold")

#wert an den jeweiligen balken schreiben:
for i, x in enumerate(NegKatTopten):
    ax.text(x+0.1, i+0, f'{x:,.1f} ', va='center', fontsize=10)

# %%
superstore.head(100)
# Out:
#           Order ID  Order Date  Order Day Order Weekday  Order Month  \
# 0   CA-2013-152156  2013-11-09          9      Saturday           11
# 1   CA-2013-152156  2013-11-09          9      Saturday           11
# 2   CA-2013-138688  2013-06-13         13      Thursday            6
# 3   US-2012-108966  2012-10-11         11      Thursday           10
# 4   US-2012-108966  2012-10-11         11      Thursday           10
# ..             ...         ...        ...           ...          ...
# 95  US-2014-109484  2014-11-07          7        Friday           11
# 96  CA-2014-161018  2014-11-10         10        Monday           11
# 97  CA-2014-157833  2014-06-18         18     Wednesday            6
# 98  CA-2013-149223  2013-09-07          7      Saturday            9
# 99  CA-2013-158568  2013-08-30         30        Friday            8
#
#     Order Year  Order Quarter   Ship Date  Ship Day Ship Weekday  ...  \
# 0         2013              4  2013-11-12        12      Tuesday  ...
# 1         2013              4  2013-11-12        12      Tuesday  ...
# 2         2013              2  2013-06-17        17       Monday  ...
# 3         2012              4  2012-10-18        18     Thursday  ...
# 4         2012              4  2012-10-18        18     Thursday  ...
# ..         ...            ...         ...       ...          ...  ...
# 95        2014              4  2014-11-13        13     Thursday  ...
# 96        2014              4  2014-11-12        12    Wednesday  ...
# 97        2014              2  2014-06-21        21     Saturday  ...
# 98        2013              3  2013-09-12        12     Thursday  ...
# 99        2013              3  2013-09-03         3      Tuesday  ...
#
#          Product ID         Category  Sub-Category  \
# 0   FUR-BO-10001798        Furniture     Bookcases
# 1   FUR-CH-10000454        Furniture        Chairs
# 2   OFF-LA-10000240  Office Supplies        Labels
# 3   FUR-TA-10000577        Furniture        Tables
# 4   OFF-ST-10000760  Office Supplies       Storage
# ..              ...              ...           ...
# 95  OFF-BI-10004738  Office Supplies       Binders
# 96  FUR-FU-10000629        Furniture   Furnishings
# 97  OFF-BI-10001721  Office Supplies       Binders
# 98  OFF-AP-10000358  Office Supplies    Appliances
# 99  OFF-PA-10003256  Office Supplies         Paper
#
#                                          Product Name     Sales Quantity  \
# 0                   Bush Somerset Collection Bookcase  261.9600        2
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2   Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3       Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                      Eldon Fold 'N Roll Cart System   22.3680        2
# ..                                                ...       ...      ...
# 95  Flexible Leather- Look Classic Collection Ring...    5.6820        1
# 96                    9-3/4 Diameter Round Wall Clock   96.5300        7
# 97                     Trimflex Flexible Post Binders   51.3120        3
# 98  Fellowes Basic Home/Office Series Surge Protec...   77.8800        6
# 99         Avery Personal Creations Heavyweight Cards   64.6240        7
#
#    Discount    Profit Price per Piece  Profit per Piece
# 0      0.00   41.9136        130.9800           20.9568
# 1      0.00  219.5820        243.9800           73.1940
# 2      0.00    6.8714          7.3100            3.4357
# 3      0.45 -383.0310        191.5155          -76.6062
# 4      0.20    2.5164         11.1840            1.2582
# ..      ...       ...             ...               ...
# 95     0.70   -3.7880          5.6820           -3.7880
# 96     0.00   40.5426         13.7900            5.7918
# 97     0.20   17.9592         17.1040            5.9864
# 98     0.00   22.5852         12.9800            3.7642
# 99     0.20   22.6184          9.2320            3.2312
#
# [100 rows x 31 columns]

# %%
import numpy as np
staateninDF=superstore["State"].unique()
staateninDF=np.sort(staateninDF)
staateninDF=pd.DataFrame(staateninDF)
#print(staateninDF)

print(superstore["State"].nunique()) #--> 49 Staaten, !!!!!!Alaska und Hawaii fehlen!!!!!!
#District of Columbia = WashingtonDC
staatenliste=["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland","Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","District of Columbia","West Virginia","Wisconsin","Wyoming","Washington"]
staatenliste.sort()
staatenliste=pd.Series(staatenliste,name="staaten")
staatenliste=pd.DataFrame(staatenliste)

#staatenliste.join(staateninDF)
staateninDF["Vergleichswert"]=staatenliste
staateninDF["Vergleichswert"][staateninDF["Vergleichswert"].isin(staateninDF[0])==False]
# Out:
# 49
# 1     Alaska
# 11    Hawaii
# Name: Vergleichswert, dtype: object

# %%
superstore["City"].nunique()#=531
CityQuant=superstore.groupby("City")["Quantity"].sum()

CityQuant.plot(kind="line")
# Out:
# <Axes: xlabel='City'>

# %%
StateQuant=superstore.groupby("State")["Quantity"].sum()
StateQuant.plot(kind="line")
# Out:
# <Axes: xlabel='State'>
