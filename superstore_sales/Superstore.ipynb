# %%
import pandas as pd

# Datei mit passendem Encoding einlesen
superstore = pd.read_csv("Superstore.csv", encoding="latin1")

# Die ersten 5 Zeilen anzeigen
superstore.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 1       2  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 2       3  CA-2013-138688  13-06-2013  17-06-2013    Second Class    DV-13045
# 3       4  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
# 4       5  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# 500 Zeilen auswählen
kurz_superstor = daten.head(500)

# In eine neue CSV speichern
kurz_superstor.to_csv("Superstore_kurz.csv", index=False)

print(" Datei Superstore_kurz.csv wurde erstellt!")
# Out:
#  Datei Superstore_kurz.csv wurde erstellt!

# %%
daten.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          9994 non-null   object
#  1   Order Date        9994 non-null   datetime64[ns]
#  2   Ship Date         9994 non-null   datetime64[ns]
#  3   Ship Mode         9994 non-null   object
#  4   Customer ID       9994 non-null   object
#  5   Segment           9994 non-null   object
#  6   City              9994 non-null   object
#  7   State             9994 non-null   object
#  8   Postal Code       9994 non-null   int64
#  9   Region            9994 non-null   object
#  10  Product ID        9994 non-null   object
#  11  Category          9994 non-null   object
#  12  Sub-Category      9994 non-null   object
#  13  Product Name      9994 non-null   object
#  14  Sales             9994 non-null   float64
#  15  Quantity          9994 non-null   int64
# ...

# %%
daten.describe()
# Out:
#                           Order Date                      Ship Date  \
# count                           9994                           9994
# mean   2013-04-30 19:20:02.401441024  2013-05-04 18:20:49.229537792
# min              2011-01-04 00:00:00            2011-01-08 00:00:00
# 25%              2012-05-23 00:00:00            2012-05-27 00:00:00
# 50%              2013-06-27 00:00:00            2013-06-30 00:00:00
# 75%              2014-05-15 00:00:00            2014-05-19 00:00:00
# max              2014-12-31 00:00:00            2015-01-06 00:00:00
# std                              NaN                            NaN
#
#         Postal Code         Sales     Quantity     Discount       Profit  \
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# ...

# %% [markdown]
# Unnötige Spalten löschen

# %%
superstore.drop(columns=["Row ID", "Country", "Customer Name"], inplace=True)

# %% [markdown]
# Datumsspalten in datetime umwandeln

# %%
superstore["Order Date"] = pd.to_datetime(daten["Order Date"], errors="coerce", dayfirst=True)
superstore["Ship Date"] = pd.to_datetime(daten["Ship Date"], errors="coerce", dayfirst=True)

# %%
superstore[daten["Order Date"].isna()]
superstore[daten["Ship Date"].isna()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Segment, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []

# %% [markdown]
# Neu spalten erstellen

# %%
# Berechnete Spalten
superstore["Preis_pro_Stück"] = daten["Sales"] / daten["Quantity"]
superstore["Profit_pro_Stück"] = daten["Profit"] / daten["Quantity"]
superstore["Lieferzeit"] = (daten["Ship Date"] - daten["Order Date"]).dt.days

# Zeitinformationen extrahieren
superstore["Order_Day"] = daten["Order Date"].dt.day
superstore["Order_Month"] = daten["Order Date"].dt.month
superstore["Order_Year"] = daten["Order Date"].dt.year
superstore["Order_Quarter"] = daten["Order Date"].dt.quarter

# %% [markdown]
# Produktmarke extrahieren

# %%
superstore["Product_Brand"] = daten["Product Name"].apply(lambda x: x.split()[0])

# %% [markdown]
# Daten überprüfen

# %%
superstore["Product_Brand"] = daten["Product Name"].apply(lambda x: x.split()[0])

# %%
daten.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          9994 non-null   object
#  1   Order Date        9994 non-null   datetime64[ns]
#  2   Ship Date         9994 non-null   datetime64[ns]
#  3   Ship Mode         9994 non-null   object
#  4   Customer ID       9994 non-null   object
#  5   Segment           9994 non-null   object
#  6   City              9994 non-null   object
#  7   State             9994 non-null   object
#  8   Postal Code       9994 non-null   int64
#  9   Region            9994 non-null   object
#  10  Product ID        9994 non-null   object
#  11  Category          9994 non-null   object
#  12  Sub-Category      9994 non-null   object
#  13  Product Name      9994 non-null   object
#  14  Sales             9994 non-null   float64
#  15  Quantity          9994 non-null   int64
# ...
